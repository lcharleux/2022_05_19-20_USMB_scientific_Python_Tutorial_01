# %% [markdown]
# # TEST GEOPANDAS
#
# install with
#
# conda install -c conda-forge geopandas

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# !ls
# Out:
# example.gpkg  read_gpkg.py  test_geopandas.ipynb

# %%
path = path_to_data = gpd.datasets.get_path("nybb")
gdf = gpd.read_file(path)

# %%
gdf.head()
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf["area"] = gdf.area
gdf['boundary'] = gdf.boundary
plt.figure()
gdf.plot("area", legend=False)
plt.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gdf.explore("area", legend=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ludch/Documents/Enseignement/Formations_Organisees/ED_SISEO/2022_SISEO/2022_05_19-20_Scientific_Python/2022_05_19-20_USMB_scientific_Python_Tutorial_01/day_2/gpkg/test_geopandas.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ludch/Documents/Enseignement/Formations_Organisees/ED_SISEO/2022_SISEO/2022_05_19-20_Scientific_Python/2022_05_19-20_USMB_scientific_Python_Tutorial_01/day_2/gpkg/test_geopandas.ipynb#ch0000006?line=0'>1</a> gdf.explore("area", legend=False)
#
# File ~/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5569'>5570</a>     and name not in self._metadata
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5570'>5571</a>     and name not in self._accessors
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5571'>5572</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5572'>5573</a> ):
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5573'>5574</a>     return self[name]
# -> <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/generic.py?line=5574'>5575</a> return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'explore'

# %%
brooklyn = gdf.loc["Brooklyn", "geometry"]
brooklyn
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/ludch/Documents/Enseignement/Formations_Organisees/ED_SISEO/2022_SISEO/2022_05_19-20_Scientific_Python/2022_05_19-20_USMB_scientific_Python_Tutorial_01/day_2/gpkg/test_geopandas.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/ludch/Documents/Enseignement/Formations_Organisees/ED_SISEO/2022_SISEO/2022_05_19-20_Scientific_Python/2022_05_19-20_USMB_scientific_Python_Tutorial_01/day_2/gpkg/test_geopandas.ipynb#ch0000007?line=0'>1</a> brooklyn = gdf.loc["Brooklyn", "geometry"]
#       <a href='vscode-notebook-cell:/home/ludch/Documents/Enseignement/Formations_Organisees/ED_SISEO/2022_SISEO/2022_05_19-20_Scientific_Python/2022_05_19-20_USMB_scientific_Python_Tutorial_01/day_2/gpkg/test_geopandas.ipynb#ch0000007?line=1'>2</a> brooklyn
#
# File ~/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=957'>958</a>     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=958'>959</a>     if self._is_scalar_access(key):
# --> <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=959'>960</a>         return self.obj._get_value(*key, takeable=self._takeable)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=960'>961</a>     return self._getitem_tuple(key)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=961'>962</a> else:
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexing.py?line=962'>963</a>     # we by definition only have the 0th axis
#
# File ~/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3615'>3616</a> engine = self.index._engine
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3617'>3618</a> if not isinstance(self.index, MultiIndex):
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3618'>3619</a>     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3619'>3620</a>     #  results if our categories are integers that dont match our codes
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3620'>3621</a>     # IntervalIndex: IntervalTree has no get_loc
# -> <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3621'>3622</a>     row = self.index.get_loc(index)
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3622'>3623</a>     return series._values[row]
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3624'>3625</a> # For MultiIndex going through engine effectively restricts us to
#    <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py?line=3625'>3626</a> #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/range.py?line=386'>387</a>             raise KeyError(key) from err
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/range.py?line=387'>388</a>     self._check_indexing_error(key)
# --> <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/range.py?line=388'>389</a>     raise KeyError(key)
#     <a href='file:///home/ludch/miniconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/range.py?line=389'>390</a> return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Brooklyn'
